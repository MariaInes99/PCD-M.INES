# %%
import pandas as pd
from sklearn import datasets
from sklearn.decomposition import PCA

# %%
url="https://raw.githubusercontent.com/masterfloss/data/main/dadosMundo.csv" 
df=pd.read_csv(url)

# %%
df
# Out:
#             Country  Area_km2  Population  Birth rate(births/1000 population)  \
# 0       Afghanistan    647500  29928987.0                               47.02
# 1          Akrotiri       123         NaN                                 NaN
# 2           Albania     28748   3563112.0                               15.08
# 3           Algeria   2381740  32531853.0                               17.13
# 4    American Samoa       199     57881.0                               23.13
# ..              ...       ...         ...                                 ...
# 258       West Bank      5860   2385615.0                               32.37
# 259  Western Sahara    266000    273008.0                                 NaN
# 260           Yemen    527970  20727063.0                               43.07
# 261          Zambia    752614  11261795.0                               41.38
# 262        Zimbabwe    390580  12746990.0                               29.74
#
#      Death rate(deaths/1000 population)  \
# 0                                 20.75
# 1                                   NaN
# 2                                  5.12
# 3                                  4.60
# 4                                  3.33
# ..                                  ...
# 258                                3.99
# 259                                 NaN
# 260                                8.53
# 261                               20.23
# 262                               24.66
#
#      Electricity – consumption(kWh) per capita  \
# 0                                    21.791583
# 1                                          NaN
# 2                                  1897.217938
# 3                                   725.750236
# 4                                  2088.768335
# ..                                         ...
# 258                                        NaN
# 259                                 306.584422
# 260                                 136.391731
# 261                                 474.613505
# 262                                 880.207798
#
#      Electricity – production(kWh) per capita  GDPpercapita  \
# 0                                   18.042709         800.0
# 1                                         NaN           NaN
# 2                                 1594.112113        4900.0
# 3                                  791.839309        6600.0
# 4                                 2245.987457        8000.0
# ..                                        ...           ...
# 258                                       NaN         800.0
# 259                                329.660669           NaN
# 260                                146.668151         800.0
# 261                                725.195229         900.0
# 262                                693.418603        1900.0
#
#      GDP - real growth rate(%)  Industrial production growth rate(%)  ...  \
# 0                          7.5                                   NaN  ...
# 1                          NaN                                   NaN  ...
# 2                          5.6                                   3.1  ...
# 3                          6.1                                   6.0  ...
# 4                          NaN                                   NaN  ...
# ..                         ...                                   ...  ...
# 258                        6.0                                   NaN  ...
# 259                        NaN                                   NaN  ...
# 260                        1.9                                   3.0  ...
# 261                        4.6                                   6.9  ...
# 262                       -8.2                                  -7.8  ...
#
#      Internet users in the per 1000 people  \
# 0                                 0.033412
# 1                                      NaN
# 2                                 8.419606
# 3                                15.369552
# 4                                      NaN
# ..                                     ...
# 258                              60.780973
# 259                                    NaN
# 260                               4.824610
# 261                               6.055873
# 262                              39.224946
#
#      Investment (gross fixed)(% of GDP)  Life expectancy at birth(years)  \
# 0                                   NaN                            42.90
# 1                                   NaN                              NaN
# 2                                  18.4                            77.24
# 3                                  26.2                            73.00
# 4                                   NaN                            75.84
# ..                                  ...                              ...
# 258                                 NaN                            73.08
# 259                                 NaN                              NaN
# 260                                16.1                            61.75
# 261                                41.4                            39.70
# 262                                 9.9                            36.67
#
#      MilitPercentGDP  Oil – consumption(bbl/day) per 1000 persons  \
# 0               2.60                                     0.116943
# 1                NaN                                          NaN
# 2               1.49                                     2.104902
# 3               3.20                                     6.424473
# 4                NaN                                    65.651941
# ..               ...                                          ...
# 258              NaN                                          NaN
# 259              NaN                                     6.593213
# 260             7.80                                     3.763196
# 261             1.80                                     0.976754
# 262             4.30                                     1.804348
#
#      Public debt(% of GDP)  Telephones - main lines in use per capita  \
# 0                      NaN                                   0.001106
# 1                      NaN                                        NaN
# 2                      NaN                                   0.071567
# 3                     37.4                                   0.067614
# 4                      NaN                                   0.259152
# ..                     ...                                        ...
# 258                    NaN                                   0.126424
# 259                    NaN                                        NaN
# 260                   46.4                                   0.026159
# 261                  127.5                                   0.007850
# 262                   52.3                                   0.023606
#
#      Telephones - mobile cellular per capita  \
# 0                                   0.000501
# 1                                        NaN
# 2                                   0.308719
# 3                                   0.044489
# 4                                   0.041067
# ..                                       ...
# 258                                 0.201206
# 259                                      NaN
# 260                                 0.019834
# 261                                 0.021400
# 262                                 0.029740
#
#      Total fertility rate(children born/woman)  Unemploy rate(%)
# 0                                         6.75               NaN
# 1                                          NaN               NaN
# 2                                         2.04              14.8
# 3                                         1.92              25.4
# 4                                         3.25               6.0
# ..                                         ...               ...
# 258                                       4.40              27.2
# 259                                        NaN               NaN
# 260                                       6.67              35.0
# 261                                       5.47              50.0
# 262                                       3.54              70.0
#
# [263 rows x 22 columns]

# %%
df.dtypes
# Out:
# Country                                            object
# Area_km2                                            int64
# Population                                        float64
# Birth rate(births/1000 population)                float64
# Death rate(deaths/1000 population)                float64
# Electricity – consumption(kWh) per capita         float64
# Electricity – production(kWh) per capita          float64
# GDPpercapita                                      float64
# GDP - real growth rate(%)                         float64
# Industrial production growth rate(%)              float64
# Infant mortality rate(deaths/1000 live births)    float64
# Inflation rate (consumer prices)(%)               float64
# Internet users in the per 1000 people             float64
# Investment (gross fixed)(% of GDP)                float64
# Life expectancy at birth(years)                   float64
# MilitPercentGDP                                   float64
# Oil – consumption(bbl/day) per 1000 persons       float64
# Public debt(% of GDP)                             float64
# Telephones - main lines in use per capita         float64
# Telephones - mobile cellular per capita           float64
# Total fertility rate(children born/woman)         float64
# Unemploy rate(%)                                  float64
# dtype: object

# %%
df['Country']=float('Country')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b4e9c09049f1> in <module>
# ----> 1 df['Country']=float('Country')
#
# ValueError: could not convert string to float: 'Country'

# %%
X=df.dropna()
PCAModel = PCA(n_components=4)
XPCA = PCAModel.fit(self,X).transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a4acf3b0126e> in <module>
#       1 X=df.dropna()
#       2 PCAModel = PCA(n_components=4)
# ----> 3 XPCA = PCAModel.fit(self,X).transform(X)
#
# NameError: name 'self' is not defined
